# %%
import numpy as np
import matplotlib.pyplot as plt
from NumOpt.OptimizationProblem import OptimizationProblem

# %%
def func(x):
    assert len(x) == 2, "Input must be a 2-dimensional vector."
    x1, x2 = x[0], x[1]
    f = 0.1*x1**6 - 1.5*x1**4 + 5*x1**2 + 0.1*x2**4 + 3*x2**2 - 9*x2 + 0.5*x1*x2
    return f

# %%
prob = OptimizationProblem(nDim=2, bounds=[(-3.5,3.5), (0,3)])
prob.setObjectiveFunction(func)
history = prob.solve(x0=[-1.5, 0.1], directionMethod='steepest_descent', stepMethod='backtracking', options={'maxiter':500, 'tol':1e-4})
prob.plotSolutionHistory(history)
prob.plotFunctionDecreaseHistory(history)

# %%
prob = OptimizationProblem(nDim=2, bounds=[(-3.5,3.5), (0,3)])
prob.setObjectiveFunction(func)
history = prob.solve(x0=[-1.5, 0.1], directionMethod='steepest_descent', stepMethod='strong_wolfe', options={'maxiter':500, 'tol':1e-4})
prob.plotSolutionHistory(history)
prob.plotFunctionDecreaseHistory(history)

# %%
prob = OptimizationProblem(nDim=2, bounds=[(-3.5,3.5), (0,3)])
prob.setObjectiveFunction(func)
history = prob.solve(x0=[-1.5, 0.1], directionMethod='quasi_newton', stepMethod='strong_wolfe', options={'maxiter':1000, 'tol':1e-4, 'mu2':0.1})
prob.plotSolutionHistory(history)
prob.plotFunctionDecreaseHistory(history)
