# %%
import numpy as np
import matplotlib.pyplot as plt
from NumOpt.functions import beanFunction
from NumOpt.OptimizationProblem import OptimizationProblem

# %%
prob = OptimizationProblem(nDim=2, bounds=[(-3.0, 3.0), (-1.0, 3.0)])
prob.setObjectiveFunction(beanFunction)
history = prob.solve(x0=[-1.0, 2.0], directionMethod='steepest_descent', stepMethod='backtracking')
prob.plotSolutionHistory(history)
prob.plotFunctionDecreaseHistory(history)

# %%
prob = OptimizationProblem(nDim=2, bounds=[(-3.0, 3.0), (-1.0, 3.0)])
prob.setObjectiveFunction(beanFunction)
history = prob.solve(x0=[-1.0, 2.0], directionMethod='conjugate_gradient', stepMethod='strong_wolfe', options={'mu1':1e-4, 'mu2':0.1})
prob.plotSolutionHistory(history)
prob.plotFunctionDecreaseHistory(history)

# %%
prob = OptimizationProblem(nDim=2, bounds=[(-3.0, 3.0), (-1.0, 3.0)])
prob.setObjectiveFunction(beanFunction)
history = prob.solve(x0=[-2.8, 1.0], directionMethod='quasi_newton', stepMethod='strong_wolfe', options={'mu1':1e-4, 'mu2':0.01})
prob.plotSolutionHistory(history)
prob.plotFunctionDecreaseHistory(history)
